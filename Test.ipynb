# %% [markdown]
# <a href="https://colab.research.google.com/github/CappyCap17/Module1/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hellow world")
# Out:
# Hellow world
